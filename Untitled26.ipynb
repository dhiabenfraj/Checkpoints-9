# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.frequent_patterns import apriori,association_rules

# %%
df=pd.read_csv('Market_Basket_Optimisation.csv', header=None)

itemlist=[]
for i in range(0, df.shape[0]):
    itemlist.extend(df.iloc[i,:].values)
itemlist=set(itemlist)
item_dict={'item':list(itemlist)}

trans_df=pd.DataFrame(item_dict)
trans_df=trans_df.iloc[1:,:].reset_index()

for i in range(0,df.shape[0]):
    trans_df[i]=trans_df.item.apply(lambda x: 1 if x in df.iloc[i,:].values else 0)

trans_df=trans_df.T
trans_df.columns=trans_df.iloc[1,:]
df=trans_df.iloc[2:,:]              # PREPROCESSED DATASET

# %%
frequent_itemsets = apriori(df, min_support=0.01,use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets
# Out:
#        support                                  itemsets  length
# 0    0.0273297                             (yogurt cake)       1
# 1    0.0505266                                    (soup)       1
# 2    0.0430609                             (fresh bread)       1
# 3    0.0155979                             (light cream)       1
# 4    0.0107986                          (barbecue sauce)       1
# ..         ...                                       ...     ...
# 252  0.0158646     (spaghetti, mineral water, chocolate)       3
# 253  0.0130649               (mineral water, eggs, milk)       3
# 254  0.0110652  (frozen vegetables, mineral water, milk)       3
# 255  0.0139981          (mineral water, milk, chocolate)       3
# 256  0.0134649          (eggs, mineral water, chocolate)       3
#
# [257 rows x 3 columns]

# %%
frequent_itemsets[frequent_itemsets.length==2].sort_values(by=['length','support'], ascending=False)
# Out:
#        support                             itemsets  length
# 173  0.0597254           (spaghetti, mineral water)       2
# 217  0.0526596           (mineral water, chocolate)       2
# 202  0.0509265                (eggs, mineral water)       2
# 194  0.0479936                (mineral water, milk)       2
# 131  0.0409279         (ground beef, mineral water)       2
# ..         ...                                  ...     ...
# 159  0.0102653            (cake, frozen vegetables)       2
# 183  0.0102653                (spaghetti, red wine)       2
# 215  0.0102653             (mineral water, cereals)       2
# 78    0.010132                    (soup, chocolate)       2
# 237   0.010132  (low fat yogurt, frozen vegetables)       2
#
# [165 rows x 3 columns]

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.2)
rules["antecedents_length"] = rules["antecedents"].apply(lambda x: len(x))
rules["consequents_length"] = rules["consequents"].apply(lambda x: len(x))
rules.sort_values("lift",ascending=False)
# Out:
#                     antecedents                 consequents  \
# 87              (herb & pepper)               (ground beef)
# 86                (ground beef)             (herb & pepper)
# 261  (spaghetti, mineral water)               (ground beef)
# 264               (ground beef)  (spaghetti, mineral water)
# 249  (spaghetti, mineral water)                 (olive oil)
# ..                          ...                         ...
# 204            (low fat yogurt)                      (eggs)
# 236                 (green tea)                    (shrimp)
# 237                    (shrimp)                 (green tea)
# 140              (french fries)                  (escalope)
# 141                  (escalope)              (french fries)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 87             0.049460            0.098254  0.015998    0.323450  3.291994
# 86             0.098254            0.049460  0.015998    0.162822  3.291994
# 261            0.059725            0.098254  0.017064    0.285714  2.907928
# 264            0.098254            0.059725  0.017064    0.173677  2.907928
# 249            0.059725            0.065858  0.010265    0.171875  2.609786
# ..                  ...                 ...       ...         ...       ...
# 204            0.076523            0.179709  0.016798    0.219512  1.221484
# 236            0.132116            0.071457  0.011465    0.086781  1.214449
# 237            0.071457            0.132116  0.011465    0.160448  1.214449
# 140            0.170911            0.079323  0.016398    0.095944  1.209537
# 141            0.079323            0.170911  0.016398    0.206723  1.209537
#
#      leverage  conviction  antecedents_length  consequents_length
# 87   0.011138    1.332860                   1                   1
# 86   0.011138    1.135410                   1                   1
# 261  0.011196    1.262445                   2                   1
# 264  0.011196    1.137902                   1                   2
# 249  0.006332    1.128021                   2                   1
# ..        ...         ...                 ...                 ...
# 204  0.003046    1.050997                   1                   1
# 236  0.002025    1.016780                   1                   1
# 237  0.002025    1.033747                   1                   1
# 140  0.002841    1.018385                   1                   1
# 141  0.002841    1.045145                   1                   1
#
# [348 rows x 11 columns]

# %%
rules[rules['consequent support']<0.15].sort_values("lift",ascending=False)
# Out:
#                     antecedents                 consequents  \
# 87              (herb & pepper)               (ground beef)
# 86                (ground beef)             (herb & pepper)
# 261  (spaghetti, mineral water)               (ground beef)
# 264               (ground beef)  (spaghetti, mineral water)
# 249  (spaghetti, mineral water)                 (olive oil)
# ..                          ...                         ...
# 7                   (chocolate)                      (soup)
# 205                      (eggs)            (low fat yogurt)
# 236                 (green tea)                    (shrimp)
# 237                    (shrimp)                 (green tea)
# 140              (french fries)                  (escalope)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 87             0.049460            0.098254  0.015998    0.323450  3.291994
# 86             0.098254            0.049460  0.015998    0.162822  3.291994
# 261            0.059725            0.098254  0.017064    0.285714  2.907928
# 264            0.098254            0.059725  0.017064    0.173677  2.907928
# 249            0.059725            0.065858  0.010265    0.171875  2.609786
# ..                  ...                 ...       ...         ...       ...
# 7              0.163845            0.050527  0.010132    0.061839  1.223888
# 205            0.179709            0.076523  0.016798    0.093472  1.221484
# 236            0.132116            0.071457  0.011465    0.086781  1.214449
# 237            0.071457            0.132116  0.011465    0.160448  1.214449
# 140            0.170911            0.079323  0.016398    0.095944  1.209537
#
#      leverage  conviction  antecedents_length  consequents_length
# 87   0.011138    1.332860                   1                   1
# 86   0.011138    1.135410                   1                   1
# 261  0.011196    1.262445                   2                   1
# 264  0.011196    1.137902                   1                   2
# 249  0.006332    1.128021                   2                   1
# ..        ...         ...                 ...                 ...
# 7    0.001853    1.012058                   1                   1
# 205  0.003046    1.018696                   1                   1
# 236  0.002025    1.016780                   1                   1
# 237  0.002025    1.033747                   1                   1
# 140  0.002841    1.018385                   1                   1
#
# [229 rows x 11 columns]
